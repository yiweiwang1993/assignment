# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("data/dataset.csv")
print(len(df.columns))
print(len(df.index))
# Out:
# 10
# 10

# %%
df=pd.read_csv("data/dataset.csv")
df.head(10)
# Out:
#    year  employment_ratio  household_expenditure  export_value_index  \
# 0  2006         63.119999           9.980000e+12          131.211585
# 1  2007         62.990002           1.020000e+13          146.843915
# 2  2008         62.180000           1.020000e+13          164.651792
# 3  2009         59.320000           1.000000e+13          135.058024
# 4  2010         58.470001           1.020000e+13          163.507554
# 5  2011         58.369999           1.040000e+13          189.598909
# 6  2012         58.560001           1.060000e+13          197.680959
# 7  2013         58.580002           1.070000e+13          202.015173
# 8  2014         59.009998           1.100000e+13          207.250875
# 9  2015         59.340000           1.140000e+13          192.464472
#
#     energy_use  net_portfolio_investment  import_value_index  population  \
# 0  7697.652535             -6.330000e+11          152.312952   298379912
# 1  7758.165986             -7.760000e+11          160.438577   301231207
# 2  7488.081921             -8.080000e+11          172.277225   304093966
# 3  7056.783653              1.853000e+10          127.475240   306771529
# 4  7160.939243             -6.210000e+11          156.371309   309348193
# 5  7028.152876             -2.260000e+11          179.943142   311663358
# 6  6869.385326             -4.980000e+11          185.541493   313998379
# 7  6902.432830             -3.068600e+10          184.948765   316204908
# 8  6956.813731             -1.190000e+11          191.578418   318563456
# 9  6800.654493             -9.696900e+10          183.272106   320896618
#
#             GDP        SP500
# 0  1.480000e+13  1318.309153
# 1  1.510000e+13  1478.095825
# 2  1.500000e+13  1215.221659
# 3  1.460000e+13   948.517492
# 4  1.500000e+13  1130.681661
# 5  1.520000e+13  1280.755829
# 6  1.550000e+13  1386.505005
# 7  1.580000e+13  1652.294169
# 8  1.620000e+13  1944.414154
# 9  1.660000e+13  2051.929169

# %%
#Create a column called "class" and randomly add a "1", "2", or "3" for every row.
df['randNumCol'] = np.random.randint(1, 4, df.shape[0])
df['randNumCol'].head(10)
print(df)
# Out:
#    year  employment_ratio  household_expenditure  export_value_index  \
# 0  2006         63.119999           9.980000e+12          131.211585
# 1  2007         62.990002           1.020000e+13          146.843915
# 2  2008         62.180000           1.020000e+13          164.651792
# 3  2009         59.320000           1.000000e+13          135.058024
# 4  2010         58.470001           1.020000e+13          163.507554
# 5  2011         58.369999           1.040000e+13          189.598909
# 6  2012         58.560001           1.060000e+13          197.680959
# 7  2013         58.580002           1.070000e+13          202.015173
# 8  2014         59.009998           1.100000e+13          207.250875
# 9  2015         59.340000           1.140000e+13          192.464472
#
#     energy_use  net_portfolio_investment  import_value_index  population  \
# 0  7697.652535             -6.330000e+11          152.312952   298379912
# 1  7758.165986             -7.760000e+11          160.438577   301231207
# 2  7488.081921             -8.080000e+11          172.277225   304093966
# 3  7056.783653              1.853000e+10          127.475240   306771529
# 4  7160.939243             -6.210000e+11          156.371309   309348193
# 5  7028.152876             -2.260000e+11          179.943142   311663358
# 6  6869.385326             -4.980000e+11          185.541493   313998379
# 7  6902.432830             -3.068600e+10          184.948765   316204908
# 8  6956.813731             -1.190000e+11          191.578418   318563456
# 9  6800.654493             -9.696900e+10          183.272106   320896618
#
#             GDP        SP500  randNumCol
# 0  1.480000e+13  1318.309153           3
# 1  1.510000e+13  1478.095825           1
# 2  1.500000e+13  1215.221659           1
# 3  1.460000e+13   948.517492           1
# 4  1.500000e+13  1130.681661           1
# 5  1.520000e+13  1280.755829           1
# 6  1.550000e+13  1386.505005           3
# 7  1.580000e+13  1652.294169           1
# 8  1.620000e+13  1944.414154           1
# 9  1.660000e+13  2051.929169           1

# %%
#Show names of all columns and rename columns as necesary
print(df.columns)
print(df.index)

df.rename(columns={df.columns[10]:'RandomClass'}, inplace=True)
df.columns
# Out:
# Index(['year', 'employment_ratio', 'household_expenditure',
#        'export_value_index', 'energy_use', 'net_portfolio_investment',
#        'import_value_index', 'population', 'GDP', 'SP500', 'randNumCol'],
#       dtype='object')
# RangeIndex(start=0, stop=10, step=1)
# Index(['year', 'employment_ratio', 'household_expenditure',
#        'export_value_index', 'energy_use', 'net_portfolio_investment',
#        'import_value_index', 'population', 'GDP', 'SP500', 'RandomClass'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    year  employment_ratio  household_expenditure  export_value_index  \
# 0  2006         63.119999           9.980000e+12          131.211585
# 1  2007         62.990002           1.020000e+13          146.843915
# 2  2008         62.180000           1.020000e+13          164.651792
# 3  2009         59.320000           1.000000e+13          135.058024
# 4  2010         58.470001           1.020000e+13          163.507554
# 5  2011         58.369999           1.040000e+13          189.598909
# 6  2012         58.560001           1.060000e+13          197.680959
# 7  2013         58.580002           1.070000e+13          202.015173
# 8  2014         59.009998           1.100000e+13          207.250875
# 9  2015         59.340000           1.140000e+13          192.464472
#
#     energy_use  net_portfolio_investment  import_value_index  population  \
# 0  7697.652535             -6.330000e+11          152.312952   298379912
# 1  7758.165986             -7.760000e+11          160.438577   301231207
# 2  7488.081921             -8.080000e+11          172.277225   304093966
# 3  7056.783653              1.853000e+10          127.475240   306771529
# 4  7160.939243             -6.210000e+11          156.371309   309348193
# 5  7028.152876             -2.260000e+11          179.943142   311663358
# 6  6869.385326             -4.980000e+11          185.541493   313998379
# 7  6902.432830             -3.068600e+10          184.948765   316204908
# 8  6956.813731             -1.190000e+11          191.578418   318563456
# 9  6800.654493             -9.696900e+10          183.272106   320896618
#
#             GDP        SP500  RandomClass
# 0  1.480000e+13  1318.309153            3
# 1  1.510000e+13  1478.095825            1
# 2  1.500000e+13  1215.221659            1
# 3  1.460000e+13   948.517492            1
# 4  1.500000e+13  1130.681661            1
# 5  1.520000e+13  1280.755829            1
# 6  1.550000e+13  1386.505005            3
# 7  1.580000e+13  1652.294169            1
# 8  1.620000e+13  1944.414154            1
# 9  1.660000e+13  2051.929169            1

# %%
#Show unique attributes for a given features that are stored in the dataset
print ('year\t', df.year.unique())
print ('employment_ratio\t', df.employment_ratio.unique())
print ('household_expenditure\t', df.household_expenditure.unique())
print ('export_value_index\t', df.export_value_index.unique())
print ('energy_use\t', df.energy_use.unique())
print ('net_portfolio_investment\t', df.net_portfolio_investment.unique())
print ('import_value_index\t', df.import_value_index.unique())
print ('population\t', df.population.unique())
print ('GDP\t', df.GDP.unique())
print ('RandomClass', df.RandomClass.unique())
# Out:
# year	 [2006 2007 2008 2009 2010 2011 2012 2013 2014 2015]
# employment_ratio	 [ 63.11999893  62.99000168  62.18000031  59.31999969  58.47000122
#   58.36999893  58.56000137  58.58000183  59.00999832  59.34000015]
# household_expenditure	 [  9.98000000e+12   1.02000000e+13   1.00000000e+13   1.04000000e+13
#    1.06000000e+13   1.07000000e+13   1.10000000e+13   1.14000000e+13]
# export_value_index	 [ 131.2115848  146.8439146  164.6517921  135.058024   163.5075545
#   189.5989093  197.6809589  202.0151729  207.2508754  192.4644716]
# energy_use	 [ 7697.652535  7758.165986  7488.081921  7056.783653  7160.939243
#   7028.152876  6869.385326  6902.43283   6956.813731  6800.654493]
# net_portfolio_investment	 [ -6.33000000e+11  -7.76000000e+11  -8.08000000e+11   1.85300000e+10
#   -6.21000000e+11  -2.26000000e+11  -4.98000000e+11  -3.06860000e+10
#   -1.19000000e+11  -9.69690000e+10]
# import_value_index	 [ 152.3129516  160.438577   172.2772254  127.4752402  156.3713095
#   179.9431418  185.5414929  184.9487652  191.5784185  183.2721061]
# population	 [298379912 301231207 304093966 306771529 309348193 311663358 313998379
#  316204908 318563456 320896618]
# GDP	 [  1.48000000e+13   1.51000000e+13   1.50000000e+13   1.46000000e+13
#    1.52000000e+13   1.55000000e+13   1.58000000e+13   1.62000000e+13
#    1.66000000e+13]
# RandomClass [3 1]

# %%
#Create a crosstabulation or contingency table
#The question is “Is there a significant relationship between two features
pd.crosstab(df.household_expenditure, df.SP500)
# Out:
# SP500                  948.517492   1130.681661  1215.221659  1280.755829  \
# household_expenditure
# 9.980000e+12                     0            0            0            0
# 1.000000e+13                     1            0            0            0
# 1.020000e+13                     0            1            1            0
# 1.040000e+13                     0            0            0            1
# 1.060000e+13                     0            0            0            0
# 1.070000e+13                     0            0            0            0
# 1.100000e+13                     0            0            0            0
# 1.140000e+13                     0            0            0            0
#
# SP500                  1318.309153  1386.505005  1478.095825  1652.294169  \
# household_expenditure
# 9.980000e+12                     1            0            0            0
# 1.000000e+13                     0            0            0            0
# 1.020000e+13                     0            0            1            0
# 1.040000e+13                     0            0            0            0
# 1.060000e+13                     0            1            0            0
# 1.070000e+13                     0            0            0            1
# 1.100000e+13                     0            0            0            0
# 1.140000e+13                     0            0            0            0
#
# SP500                  1944.414154  2051.929169
# household_expenditure
# 9.980000e+12                     0            0
# 1.000000e+13                     0            0
# 1.020000e+13                     0            0
# 1.040000e+13                     0            0
# 1.060000e+13                     0            0
# 1.070000e+13                     0            0
# 1.100000e+13                     1            0
# 1.140000e+13                     0            1

# %%
#Get rid of the junk numbering and missing values
#df.Bare_Nuclei=df.Bare_Nuclei.map(lambda x: x.split('.')[-1])

df.head()
print ('household_expenditure\t', df.household_expenditure.unique())
df['household_expenditure'].replace('?', '5',inplace=True)
print ('household_expenditure\t', df.household_expenditure.unique())
# Out:
# household_expenditure	 [  9.98000000e+12   1.02000000e+13   1.00000000e+13   1.04000000e+13
#    1.06000000e+13   1.07000000e+13   1.10000000e+13   1.14000000e+13]
# household_expenditure	 [  9.98000000e+12   1.02000000e+13   1.00000000e+13   1.04000000e+13
#    1.06000000e+13   1.07000000e+13   1.10000000e+13   1.14000000e+13]

# %%
#Create a new dataframe dfsub by taking the list of one column (feature) and using pandas. 
#Apply function to divide all values by 100.

dfsub=df.iloc[:,2:3].apply(lambda x: x/100.0)
dfsub.head()
# Out:
#    household_expenditure
# 0           9.980000e+10
# 1           1.020000e+11
# 2           1.020000e+11
# 3           1.000000e+11
# 4           1.020000e+11

# %%
#Create a plot that shows two columns (features) plotted against each other (e.g. A vs. B) Create a histogram of the dataset using a selected column (feature)
import matplotlib.pyplot as plt
from pylab import *

#print(df.household_expenditure)
#print(df.SP500)
fig=plt.figure()
plt.scatter(df.household_expenditure, df.SP500)
axis = fig.gca() #get current axis
axis.set_title('household_expenditure vs SP500')
axis.set_xlabel('household_expenditure')
axis.set_ylabel('SP500')
fig

# %%
#Use a more object oriented approach by using the subplots function to set both figure and axis.
figure()
fig, axes=plt.subplots(figsize=(10,10), nrows=2, ncols=2)
axes[0][0].plot(df.household_expenditure, df.SP500)
axes[0][1].plot(df.household_expenditure, df.SP500, '.')
axes[1][0].scatter(df.household_expenditure, df.SP500)
axes[1][1].hist(df.household_expenditure)
fig.tight_layout()
show(fig)

# %%
fig=plt.hist(df.household_expenditure)
show(fig)

# %%
#Make scatterplots of a selected column "featureA" in the list yfeatureA against the featureA in the list xfeatureA. 
#As the names suggest, plot featureA in yfeatureA along the y featureA and the acids in xfeatureA along the x axis. 
#Label the axes with the respective feature name. 
#Set it up as a grid with 3 rows and 2 columns.

xfeatures=['household_expenditure','export_value_index','GDP']
yfeatures=['employment_ratio','population']

#your code here
figure()
print(len(xfeatures))
print(len(yfeatures))
fig1, axes=plt.subplots(figsize=(10,10), nrows=len(xfeatures), ncols=len(yfeatures))
for i, xfeature in enumerate(xfeatures):
    for j, yfeature in enumerate(yfeatures):
        axes[i][j].scatter(df[xfeature],df[yfeature])
        axes[i][j].set_xlabel(xfeature)
        axes[i][j].set_ylabel(yfeature)
fig1.tight_layout()
show(fig1)
# Out:
# 3
# 2

# %%
#The first concept we deal with here is pandas groupby. 
#Group your dataframe dfsub by the values of a particular factor variable.

RandomClass_groupby = df.groupby('RandomClass')
print (type(RandomClass_groupby))
RandomClass_groupby.head()
# Out:
# <class 'pandas.core.groupby.DataFrameGroupBy'>
#    year  employment_ratio  household_expenditure  export_value_index  \
# 0  2006         63.119999           9.980000e+12          131.211585
# 1  2007         62.990002           1.020000e+13          146.843915
# 2  2008         62.180000           1.020000e+13          164.651792
# 3  2009         59.320000           1.000000e+13          135.058024
# 4  2010         58.470001           1.020000e+13          163.507554
# 5  2011         58.369999           1.040000e+13          189.598909
# 6  2012         58.560001           1.060000e+13          197.680959
#
#     energy_use  net_portfolio_investment  import_value_index  population  \
# 0  7697.652535             -6.330000e+11          152.312952   298379912
# 1  7758.165986             -7.760000e+11          160.438577   301231207
# 2  7488.081921             -8.080000e+11          172.277225   304093966
# 3  7056.783653              1.853000e+10          127.475240   306771529
# 4  7160.939243             -6.210000e+11          156.371309   309348193
# 5  7028.152876             -2.260000e+11          179.943142   311663358
# 6  6869.385326             -4.980000e+11          185.541493   313998379
#
#             GDP        SP500  RandomClass
# 0  1.480000e+13  1318.309153            3
# 1  1.510000e+13  1478.095825            1
# 2  1.500000e+13  1215.221659            1
# 3  1.460000e+13   948.517492            1
# 4  1.500000e+13  1130.681661            1
# 5  1.520000e+13  1280.755829            1
# 6  1.550000e+13  1386.505005            3

# %%
#The groupby function also acts like an object that can be mapped. 
#After the mapping is complete, the rows are put together (reduced) into a larger dataframe. 
#Apply the describe function.

dfrd=RandomClass_groupby.describe()
print (type(dfrd))
dfrd.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#               GDP                                                          \
#             count          mean           std           min           25%
# RandomClass
# 1             8.0  1.543750e+13  6.885544e+11  1.460000e+13  1.500000e+13
# 3             2.0  1.515000e+13  4.949747e+11  1.480000e+13  1.497500e+13
#
#                                                       SP500               \
#                       50%           75%           max count         mean
# RandomClass
# 1            1.515000e+13  1.590000e+13  1.660000e+13   8.0  1462.738745
# 3            1.515000e+13  1.532500e+13  1.550000e+13   2.0  1352.407079
#
#               ...      population               year                      \
#               ...             75%          max count      mean       std
# RandomClass   ...
# 1             ...    3.167945e+08  320896618.0   8.0  2010.875  2.900123
# 3             ...    3.100938e+08  313998379.0   2.0  2009.000  4.242641
#
#
#                 min      25%     50%      75%     max
# RandomClass
# 1            2007.0  2008.75  2010.5  2013.25  2015.0
# 3            2006.0  2007.50  2009.0  2010.50  2012.0
#
# [2 rows x 80 columns]

# %%
#Standard Deviation of each feature

vecs=[]
keys=[]
for key, value in RandomClass_groupby:
    k=key
    v=value.std()
print (k, type(v), v)

#Mean and Standard Deviation indexed by Clump_Thickness
dfbystd=df.groupby('RandomClass').std()
dfbystd.head()

dfbymean=RandomClass_groupby.aggregate(np.mean)
dfbymean.head()
# Out:
# 3 <class 'pandas.core.series.Series'> year                        4.242641e+00
# employment_ratio            3.224405e+00
# household_expenditure       4.384062e+11
# export_value_index          4.700095e+01
# energy_use                  5.856734e+02
# net_portfolio_investment    9.545942e+10
# import_value_index          2.349613e+01
# population                  1.104392e+07
# GDP                         4.949747e+11
# SP500                       4.822175e+01
# RandomClass                 0.000000e+00
# dtype: float64
#                  year  employment_ratio  household_expenditure  \
# RandomClass
# 1            2010.875           59.7825           1.051250e+13
# 3            2009.000           60.8400           1.029000e+13
#
#              export_value_index   energy_use  net_portfolio_investment  \
# RandomClass
# 1                    175.173839  7144.003092             -3.323906e+11
# 3                    164.446272  7283.518931             -5.655000e+11
#
#              import_value_index    population           GDP        SP500
# RandomClass
# 1                    169.538098  3.110967e+08  1.543750e+13  1462.738745
# 3                    168.927222  3.061891e+08  1.515000e+13  1352.407079

# %%
featurelist1=['year', 'employment_ratio',
       'household_expenditure', 'export_value_index',
       'energy_use', 'net_portfolio_investment', 'import_value_index',
       'population', 'GDP', 'SP500']

renamedict_std={k:k+"_std" for k in featurelist1}
renamedict_mean={k:k+"_mean" for k in featurelist1}
dfbystd.rename(inplace=True, columns=renamedict_std)
dfbymean.rename(inplace=True, columns=renamedict_mean) 
dfbystd.head()
# Out:
#              year_std  employment_ratio_std  household_expenditure_std  \
# RandomClass
# 1            2.900123              1.781106               4.823677e+11
# 3            4.242641              3.224405               4.384062e+11
#
#              export_value_index_std  energy_use_std  \
# RandomClass
# 1                         26.498305      322.531493
# 3                         47.000945      585.673360
#
#              net_portfolio_investment_std  import_value_index_std  \
# RandomClass
# 1                            3.449095e+11               20.884392
# 3                            9.545942e+10               23.496127
#
#              population_std       GDP_std   SP500_std
# RandomClass
# 1              7.033962e+06  6.885544e+11  393.589988
# 3              1.104392e+07  4.949747e+11   48.221749

# %%
dfpalmiticmean = dfbymean[['GDP_mean']] 
dfpalmiticstd = dfbystd[['GDP_std']] 

newdfbyregion=dfpalmiticmean.join(dfpalmiticstd)
newdfbyregion.head()
# Out:
#                  GDP_mean       GDP_std
# RandomClass
# 1            1.543750e+13  6.885544e+11
# 3            1.515000e+13  4.949747e+11

# %%
print(df.shape)

weights=np.random.uniform(size=df.shape[0])
smallerdf=df[['GDP']]
otherdf=df[['RandomClass']]
otherdf['weight'] = weights
otherdf.head()
# Out:
# (10, 11)
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    RandomClass    weight
# 0            3  0.768378
# 1            1  0.895285
# 2            1  0.746907
# 3            1  0.261787
# 4            1  0.586801

# %%
print(df.columns)
featurelist1=['year', 'employment_ratio',
       'household_expenditure', 'export_value_index',
       'energy_use', 'net_portfolio_investment', 'import_value_index',
       'population', 'GDP', 'SP500']

mdf2=df.groupby('RandomClass').aggregate(np.mean)
mdf2=mdf2[featurelist1]
mdf2.head()
# Out:
# Index(['year', 'employment_ratio', 'household_expenditure',
#        'export_value_index', 'energy_use', 'net_portfolio_investment',
#        'import_value_index', 'population', 'GDP', 'SP500', 'RandomClass'],
#       dtype='object')
#                  year  employment_ratio  household_expenditure  \
# RandomClass
# 1            2010.875           59.7825           1.051250e+13
# 3            2009.000           60.8400           1.029000e+13
#
#              export_value_index   energy_use  net_portfolio_investment  \
# RandomClass
# 1                    175.173839  7144.003092             -3.323906e+11
# 3                    164.446272  7283.518931             -5.655000e+11
#
#              import_value_index    population           GDP        SP500
# RandomClass
# 1                    169.538098  3.110967e+08  1.543750e+13  1462.738745
# 3                    168.927222  3.061891e+08  1.515000e+13  1352.407079

# %%
rkeys=[1,2,3]
rvals=['Time1','Time2','Time3']
rmap={e[0]:e[1] for e in zip(rkeys,rvals)}
rmap

figure()
ax=mdf2.plot(kind='barh', stacked=True)
ax.set_yticklabels(rvals)
ax.set_xlim([0,100])
show(ax)

# %%
import brewer2mpl
from matplotlib import rcParams

#colorbrewer2 Dark2 qualitative color table
dark2_cmap = brewer2mpl.get_map('Dark2', 'Qualitative', 7)
dark2_colors = dark2_cmap.mpl_colors

rcParams['figure.figsize'] = (10, 6)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['axes.facecolor'] = 'white'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'white'
rcParams['patch.facecolor'] = dark2_colors[0]
rcParams['font.family'] = 'StixGeneral'


def remove_border(axes=None, top=False, right=False, left=True, bottom=True):
    """
    Minimize chartjunk by stripping out unnecesasry plot borders and axis ticks
    
    The top/right/left/bottom keywords toggle whether the corresponding plot border is drawn
    """
    ax = axes or plt.gca()
    ax.spines['top'].set_visible(top)
    ax.spines['right'].set_visible(right)
    ax.spines['left'].set_visible(left)
    ax.spines['bottom'].set_visible(bottom)
    
    #turn off all ticks
    ax.yaxis.set_ticks_position('none')
    ax.xaxis.set_ticks_position('none')
    
    #now re-enable visibles
    if top:
        ax.xaxis.tick_top()
    if bottom:
        ax.xaxis.tick_bottom()
    if left:
        ax.yaxis.tick_left()
    if right:
        ax.yaxis.tick_right()


figure()
fig, axes=plt.subplots(figsize=(10,20), nrows=len(featurelist1), ncols=1)
i=0
colors=[dark2_cmap.mpl_colormap(col) for col in [1.0,0.5,0.0]]
for ax in axes.flatten():
    features=featurelist1[i]
    seriesMitoses=df[features]#get the Pandas series
    minmax=[seriesMitoses.min(), seriesMitoses.max()]
    counts=[]
    nbins=30
    histbinslist = np.linspace(minmax[0],  minmax[1], nbins)
    counts=-np.diff([seriesMitoses[seriesMitoses>x].count() for x in histbinslist]).min()
    for k,g in df.groupby('RandomClass'):
        style = {'histtype':'step', 'color':colors[k-1], 'alpha':1.0, 'bins':histbinslist, 'label':rmap[k]}
        ax.hist(g[features],**style)
        ax.set_xlim(minmax)
        ax.set_title(features)
        ax.grid(False)
    #construct legend
    ax.set_ylim([0, counts])
    ax.legend()
    i=i+1
fig.tight_layout()
show()
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\__init__.py:913: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
figure()
def make2d(df, scatterx, scattery, by="RandomClass", labeler={}):
    figure=plt.figure(figsize=(8,8))
    ax=plt.gca()
    cs=list(np.linspace(0,1,len(df.groupby(by))))
    xlimsd={}
    ylimsd={}
    xs={}
    ys={}
    cold={}
    for k,g in df.groupby(by):
        col=cs.pop()
        x=g[scatterx]
        y=g[scattery]
        xs[k]=x
        ys[k]=y
        c=dark2_cmap.mpl_colormap(col)
        cold[k]=c
        ax.scatter(x, y, c=c, label=labeler.get(k,k), s=40, alpha=0.4);
        xlimsd[k]=ax.get_xlim()
        ylimsd[k]=ax.get_ylim()
    xlims=[min([xlimsd[k][0] for k in xlimsd.keys()]), max([xlimsd[k][1] for k in xlimsd.keys()])]
    ylims=[min([ylimsd[k][0] for k in ylimsd.keys()]), max([ylimsd[k][1] for k in ylimsd.keys()])]
    ax.set_xlim(xlims)
    ax.set_ylim(ylims)
    ax.set_xlabel(scatterx)
    ax.set_ylabel(scattery)
    ax.grid(False)
    return ax
a=make2d(df, "SP500","GDP", labeler=rmap)
a.legend(loc='upper right');
show()

# %%
import seaborn as sns

import matplotlib.pyplot as plt

figure()
dfcopy=df.copy()
dfcopy['RandomClass']=dfcopy['RandomClass'].map(rmap)
#imap={e[0]:e[1] for e in zip (df.Class_2benign_4malignant.unique(), df.Class_2benign_4malignant.unique())}
#dfcopy['area']=dfcopy['area'].map(imap)

grid = sns.JointGrid(x="GDP", y="SP500", space=0, size=6, ratio=50, data=dfcopy)
grid.plot_joint(plt.scatter, color="g")
grid.plot_marginals(sns.rugplot, height=1, color="g")

sns.lmplot(x="GDP", y="SP500", hue="RandomClass",
               truncate=True, size=5, data=dfcopy)

#fig=plot.render()
print (df.Class_2benign_4malignant.unique())
show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-6b973641ee3a> in <module>()
#      17
#      18 #fig=plot.render()
# ---> 19 print (df.Class_2benign_4malignant.unique())
#      20 show()
#
# C:\Users\Administrator\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Class_2benign_4malignant'

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
def setup_mhist(axes, figure):
    ax1=axes
    divider = make_axes_locatable(ax1)
    ax2 = divider.append_axes("top", 1.5, pad=0.0, sharex=ax1)
    ax3 = divider.append_axes("right", 1.5, pad=0.0, sharey=ax1)
    #xscale=yscale='log'
    #ax2.set_yscale(yscale)
    #ax3.set_xscale(xscale)
    #ax2.set_ylim([0,1])
    #ax3.set_xlim([0,5])
    ax2.grid(False)
    ax3.grid(False)
    ax2.grid(axis="y", color="white", linestyle='-', lw=1)
    ax3.grid(axis="x", color="white", linestyle='-', lw=1)
    remove_border(ax2, right=True, left=False)
    remove_border(ax3, right=False, left=True, bottom=False, top=True)
    figure.subplots_adjust(left=0.15, right=0.95)
    return [ax1,ax2,ax3]

#BUG: need to get appropriate min and max amongst the multiple marginal hists
#BUG: need to get highest frequency marked as label when we do this.
def make_mhist(axeslist, x, y, color='b', mms=8):
    ax1 = axeslist[0]
    ax2 = axeslist[1]
    ax3 = axeslist[2]
    #print list(ax2.get_yticklabels())
    for tl in (ax2.get_xticklabels() + ax2.get_yticklabels() +
               ax3.get_xticklabels() + ax3.get_yticklabels()):
        tl.set_visible(False)
    #for tl in ( ax2.get_xticklabels() + ax3.get_yticklabels()):
    #    tl.set_visible(False)
    histbinslist = [np.ceil(len(x)/20.), np.ceil(len(y)/20.)]
    histbinslist = copy.copy(histbinslist)
    #style = {'histtype':'stepfilled', 'color':color, 'alpha':0.6, 'normed':True, 'stacked':True}
    style = {'histtype':'stepfilled', 'color':color, 'alpha':0.4}
    nbins = histbinslist[0]
    x_range = [np.min(x), np.max(x)]
    histbinslist[0] = np.linspace(x_range[0],  x_range[1], nbins)

    ax2.hist(x, histbinslist[0], **style)

    nbins = histbinslist[1]
    y_range = [np.min(y), np.max(y)]
    histbinslist[1] = np.linspace(y_range[0], y_range[1], nbins)
    ax3.hist(y, histbinslist[1], orientation='horizontal', **style)

# %%
import random
import copy
def scatter_by(df, scatterx, scattery, by=None, figure=None, axes=None, colorscale=dark2_cmap, labeler={}, mfunc=None, setupfunc=None, mms=8):
    cs=copy.deepcopy(colorscale.mpl_colors)
    if not figure:
        figure=plt.figure(figsize=(8,8))
    if not axes:
        axes=figure.gca()
    x=df[scatterx]
    y=df[scattery]
    if not by:
        col=random.choice(cs)
        axes.scatter(x, y, cmap=colorscale, c=col)
        if setupfunc:
            axeslist=setupfunc(axes, figure)
        else:
            axeslist=[axes]
        if mfunc:
            mfunc(axeslist,x,y,color=col, mms=mms)
    else:
        cs=list(np.linspace(0,1,len(df.groupby(by))))
        xlimsd={}
        ylimsd={}
        xs={}
        ys={}
        cold={}
        for k,g in df.groupby(by):
            col=cs.pop()
            x=g[scatterx]
            y=g[scattery]
            xs[k]=x
            ys[k]=y
            c=colorscale.mpl_colormap(col)
            cold[k]=c
            axes.scatter(x, y, c=c, label=labeler.get(k,k), s=40, alpha=0.3);
            xlimsd[k]=axes.get_xlim()
            ylimsd[k]=axes.get_ylim()
        xlims=[min([xlimsd[k][0] for k in xlimsd.keys()]), max([xlimsd[k][1] for k in xlimsd.keys()])]
        ylims=[min([ylimsd[k][0] for k in ylimsd.keys()]), max([ylimsd[k][1] for k in ylimsd.keys()])]
        axes.set_xlim(xlims)
        axes.set_ylim(ylims)
        if setupfunc:
            axeslist=setupfunc(axes, figure)
        else:
            axeslist=[axes]
        if mfunc:
            for k in xs.keys():
                mfunc(axeslist,xs[k],ys[k],color=cold[k], mms=mms);
    axes.set_xlabel(scatterx);
    axes.set_ylabel(scattery);
    
    return axes

def make_rug(axeslist, x, y, color='b', mms=8):
    axes=axeslist[0]
    zerosx1=np.zeros(len(x))
    zerosx2=np.zeros(len(x))
    xlims=axes.get_xlim()
    ylims=axes.get_ylim()
    zerosx1.fill(ylims[1])
    zerosx2.fill(xlims[1])
    axes.plot(x, zerosx1, marker='|', color=color, ms=mms)
    axes.plot(zerosx2, y, marker='_', color=color, ms=mms)
    axes.set_xlim(xlims)
    axes.set_ylim(ylims)
    return axes

# %%
figure()
ax=scatter_by(df, 'GDP', 'SP500', by='RandomClass', labeler=rmap, mfunc=make_rug, mms=20)
ax.grid(False)
ax.legend(loc='upper right');
show()

figure()
ax=scatter_by(df, 'GDP', 'SP500', by='RandomClass', labeler=rmap, setupfunc=setup_mhist, mfunc=make_mhist, mms=20)
ax.grid(False)
ax.legend(loc='upper right');
show()
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: DeprecationWarning: object of type <class 'numpy.float64'> cannot be safely interpreted as an integer.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-d92b8e99ea93> in <module>()
#       6
#       7 figure()
# ----> 8 ax=scatter_by(df, 'GDP', 'SP500', by='RandomClass', labeler=rmap, setupfunc=setup_mhist, mfunc=make_mhist, mms=20)
#       9 ax.grid(False)
#      10 ax.legend(loc='upper right');
#
# <ipython-input-30-08603e345ee9> in scatter_by(df, scatterx, scattery, by, figure, axes, colorscale, labeler, mfunc, setupfunc, mms)
#      46         if mfunc:
#      47             for k in xs.keys():
# ---> 48                 mfunc(axeslist,xs[k],ys[k],color=cold[k], mms=mms);
#      49     axes.set_xlabel(scatterx);
#      50     axes.set_ylabel(scattery);
#
# <ipython-input-29-50ae51edfa60> in make_mhist(axeslist, x, y, color, mms)
#      39     histbinslist[0] = np.linspace(x_range[0],  x_range[1], nbins)
#      40
# ---> 41     ax2.hist(x, histbinslist[0], **style)
#      42
#      43     nbins = histbinslist[1]
#
# C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1895                     warnings.warn(msg % (label_namer, func.__name__),
#    1896                                   RuntimeWarning, stacklevel=2)
# -> 1897             return func(ax, *args, **kwargs)
#    1898         pre_doc = inner.__doc__
#    1899         if pre_doc is None:
#
# C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(***failed resolving arguments***)
#    6362                     facecolor=c,
#    6363                     edgecolor=None if fill else c,
# -> 6364                     fill=fill if fill else None))
#    6365             for patch_list in patches:
#    6366                 for patch in patch_list:
#
# C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1895                     warnings.warn(msg % (label_namer, func.__name__),
#    1896                                   RuntimeWarning, stacklevel=2)
# -> 1897             return func(ax, *args, **kwargs)
#    1898         pre_doc = inner.__doc__
#    1899         if pre_doc is None:
#
# C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in fill(self, *args, **kwargs)
#    4695
#    4696         patches = []
# -> 4697         for poly in self._get_patches_for_fill(*args, **kwargs):
#    4698             self.add_patch(poly)
#    4699             patches.append(poly)
#
# C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _grab_next_args(self, *args, **kwargs)
#     405                 return
#     406             if len(remaining) <= 3:
# --> 407                 for seg in self._plot_args(remaining, kwargs):
#     408                     yield seg
#     409                 return
#
# C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     393         ncx, ncy = x.shape[1], y.shape[1]
#     394         for j in xrange(max(ncx, ncy)):
# --> 395             seg = func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     396             ret.append(seg)
#     397         return ret
#
# C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _makefill(self, x, y, kw, kwargs)
#     348                                facecolor=facecolor,
#     349                                fill=kwargs.get('fill', True),
# --> 350                                closed=kw['closed'])
#     351         self.set_patchprops(seg, **kwargs)
#     352         return seg
#
# C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\patches.py in __init__(self, xy, closed, **kwargs)
#     950         Patch.__init__(self, **kwargs)
#     951         self._closed = closed
# --> 952         self.set_xy(xy)
#     953
#     954     def get_path(self):
#
# C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\patches.py in set_xy(self, xy)
#    1019             if len(xy) > 2 and (xy[0] == xy[-1]).all():
#    1020                 xy = xy[:-1]
# -> 1021         self._path = Path(xy, closed=self._closed)
#    1022         self.stale = True
#    1023
#
# C:\Users\Administrator\Anaconda3\lib\site-packages\matplotlib\path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     153         elif closed:
#     154             codes = np.empty(len(vertices), dtype=self.code_type)
# --> 155             codes[0] = self.MOVETO
#     156             codes[1:-1] = self.LINETO
#     157             codes[-1] = self.CLOSEPOLY
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
import scipy.stats as stats
mu=0.
sigma=1.
samples=np.random.normal(mu, sigma, 10000)

figure()
plt.hist(samples,bins=25, normed=True)
nd=stats.norm()
plt.hist(nd.rvs(size=10000), bins=25, alpha=0.5,normed=True)
x=np.linspace(-4.0,4.0,100)
plt.plot(x,nd.pdf(x))
plt.plot(x,nd.cdf(x))
show()

# %%
from pandas.tools.plotting import parallel_coordinates
dfna=df[['year', 'employment_ratio',
       'household_expenditure', 'export_value_index',
       'energy_use', 'net_portfolio_investment', 'import_value_index',
       'population', 'GDP', 'SP500']]
dfna_norm = (dfna - dfna.mean()) / (dfna.max() - dfna.min())
dfna_norm['RandomClass']=df['RandomClass'].map(lambda x: rmap[x])
parallel_coordinates(dfna_norm, 'RandomClass', colors=[dark2_cmap.mpl_colormap(col) for col in [1.0,0.5,0.0]], alpha=0.05)
show()
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: 'pandas.tools.plotting.parallel_coordinates' is deprecated, import 'pandas.plotting.parallel_coordinates' instead.
#
# C:\Users\Administrator\Anaconda3\lib\site-packages\pandas\tools\plotting.py:17: FutureWarning: the 'colors' keyword is deprecated, use 'color' instead
#   return getattr(_plotting, t)(*args, **kwargs)
